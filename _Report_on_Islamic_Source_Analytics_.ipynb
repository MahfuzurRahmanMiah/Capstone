# %% [markdown]
# Approximately 1.8 billion people are adherants to the religion of Islam, referring to themselves as Muslims, but there is probably more misinformation than truth known about this faith here in the West. Muslims refer back to two main bodies of texts, the Qur'an and the Hadith. While most know that the Qur'an is to the Muslims what the Torah is to the Jews and what the Bible is to Christians, fewer people know about the Hadith. The Encyclopedia Britannica defines Hadith as a "record of the traditions or sayings of the Prophet Muhammad, revered and received as a major source of religious law and moral guidance, second only to the authority of the Qurʾān, the holy book of Islam." Can we determine who are the main players in conributing to the preservation of these traditions?
#
# We are working with a dataset called Hadith Narrators Dataset, found on Kaggle. The content creator mentions that he scraped the data from muslimscholars.info that provide all cross-validated metadata about each scholar from more than 10 primary sources (check their website to learn more).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
# %matplotlib inline

# Set up the data
df = pd.read_csv('all_rawis.csv')

# What's inside the file? Let's take a preview.
print(df.head())
# Out:
#    scholar_indx                                               name  \
# 0             1  Prophet Muhammad(saw) ( محمّد صلّی اللہ علیہ و...
# 1             2  Abu Bakr As-Siddique ( أبو بكر الصديق ( رضي ال...
# 2             3  'Umar ibn al-Khattab ( عمر بن الخطاب بن نفيل (...
# 3             4  'Uthman ibn 'Affaan ( عثمان بن عفان ( رضي الله...
# 4             5  Ali ibn Abi Talib ( علي بن أبي طالب بن عبد الم...
#
#                         grade  \
# 0                Rasool Allah
# 1  Comp.(RA) [1st Generation]
# 2  Comp.(RA) [1st Generation]
# 3  Comp.(RA) [1st Generation]
# 4  Comp.(RA) [1st Generation]
#
#                                              parents  \
# 0  'Abdullah ibn 'Abd al-Muttalib [9991] / Amina ...
# 1  Abu Quhafa Uthman bin 'Amir [500] / Salma Umm-...
# 2  Khattab ibn Nufayl / Hantamah bint Hisham Makh...
# 3  'Affan ibn Abi al-'As / Arwa bint Kuraiz bin R...
# 4  Abu Talib ibn 'Abd al-Muttalib [9992] / Fatima...
#
# ...

# %% [markdown]
# Only 5 columns have numbers/dates.

# %%
df.describe()
# Out:
#        scholar_indx  birth_date_hijri  birth_date_gregorian  death_date_hijri  \
# count  24326.000000        386.000000            106.000000       3951.000000
# mean   17951.338033         86.220207            646.132075        149.267780
# std    11268.991643         62.357667             75.069374         86.999975
# min        1.000000          1.000000            497.000000          0.000000
# 25%     8409.250000         30.000000            594.000000         80.000000
# 50%    17007.500000         80.000000            624.500000        155.000000
# 75%    27427.750000        133.000000            690.250000        228.000000
# max    40023.000000        270.000000            839.000000        416.000000
#
#        death_date_gregorian
# count            554.000000
# mean             655.476534
# std               69.777199
# min               23.000000
# 25%              626.000000
# 50%              636.000000
# 75%              670.000000
# max              923.000000

# %% [markdown]
# **PART 1
#
# * What does your data contain and what is its background?
#
# * Where does it come from? Why is it interesting or significant?
# * Conduct summary statistics and produce visualizations for the particular variables from the dataset that you will use.
#
# * What variables does your data contain and what distributions do you think they have?
#
# * Does the data bear on the preliminary questions you wrote down?
#
# * What new questions might you answer? How does the data look when you plot it out?

# %% [markdown]
# **PART 2
#
# * Ask three analytic questions and answer each one with a combination of statistics and visualizations. These analytic questions can focus on individuals behaviors or comparisons of the population.

# %% [markdown]
# **PART 3
#
# * Propose further research. Lastly, make a proposal for a realistic future research project on this dataset that would use some data science techniques you'd like to learn in the bootcamp. Just like your earlier questions, your research proposal should present one or more clear questions. Then you should describe the techniques you would apply in order to arrive at an answer.
